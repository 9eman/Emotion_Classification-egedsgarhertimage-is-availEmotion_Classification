# %%
import pandas as pd
import os
import glob as gb
from tensorflow import keras

from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# %%
TRAIN_DIR = "C:\\Users\\almon\\Desktop\\ee\\eINTERFACE_2021_Image\\train\\"
TEST_DIR = "C:\\Users\\almon\\Desktop\\ee\\eINTERFACE_2021_Image\\test\\"
BATCH_SIZE=64

# %%
for folder in os.listdir(TRAIN_DIR):
    files = gb.glob(pathname= str(TRAIN_DIR+ '/'+ folder + '/*.jpg'))
    print(f'For training data, found {len(files)} in folder {folder}')
# Out:
# For training data, found 1896 in folder Anger
# For training data, found 1891 in folder Disgust
# For training data, found 1922 in folder Fear
# For training data, found 1922 in folder Happiness
# For training data, found 1922 in folder Sadness
# For training data, found 1922 in folder Surprise

# %%
for folder in os.listdir(TEST_DIR):
    files = gb.glob(pathname= str(TEST_DIR+ '/'+ folder + '/*.jpg'))
    print(f'For testing data, found {len(files)} in folder {folder}')
# Out:
# For testing data, found 237 in folder Anger
# For testing data, found 237 in folder Disgust
# For testing data, found 241 in folder Fear
# For testing data, found 241 in folder Happiness
# For testing data, found 241 in folder Sadness
# For testing data, found 241 in folder Surprise

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def view_random_image(target_dir, target_class):
    # We will view images from here
    target_folder = target_dir + target_class
    
    # Get a random image path
    random_image = random.sample(os.listdir(target_folder), 1)
    
    # read in the image and plot it using matplolib
    img = mpimg.imread(target_folder+'/'+random_image[0])
    plt.imshow(img)
    plt.title(target_class)
    plt.axis('off')
    print(f"Image shape {img.shape}")
    
    return img

# %%
class_names = ['Anger','Disgust','Fear','Happiness','Sadness','Surprise']

# %%
plt.figure(figsize=(20,10))
for i in range(18):
    plt.subplot(3, 6, i+1)
    class_name = random.choice(class_names)
    img = view_random_image(target_dir="C:\\Users\\almon\\Desktop\\ee\\eINTERFACE_2021_Image\\train\\", target_class=class_name)
# Out:
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)
# Image shape (416, 416, 3)

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory(TRAIN_DIR,
                                                 target_size = (128, 128),
                                                 batch_size = BATCH_SIZE,
                                                 class_mode = 'categorical')

test_set = test_datagen.flow_from_directory(TEST_DIR,
                                            target_size = (128, 128),
                                            batch_size = BATCH_SIZE,
                                            class_mode = 'categorical')
# Out:
# Found 11475 images belonging to 6 classes.
# Found 1438 images belonging to 6 classes.

# %%
# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(16, (3, 3), input_shape = (128, 128, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))



# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))

classifier.add(Dense(units = 6, activation = 'softmax'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
## model summary
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 28800)             0
#
#  dense (Dense)               (None, 128)               3686528
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 3,692,390
# Trainable params: 3,692,390
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = classifier.fit(training_set,
                         epochs = 50,
                         validation_data = test_set)


classifier.save('model1.h5')  # creates a HDF5 file 'my_model.h5'
# Out:
# Epoch 1/50
# 180/180 [==============================] - 73s 404ms/step - loss: 1.7594 - accuracy: 0.2457 - val_loss: 1.6018 - val_accuracy: 0.3554
# Epoch 2/50
# 180/180 [==============================] - 73s 405ms/step - loss: 1.5363 - accuracy: 0.3675 - val_loss: 1.4102 - val_accuracy: 0.4172
# Epoch 3/50
# 180/180 [==============================] - 73s 406ms/step - loss: 1.3352 - accuracy: 0.4518 - val_loss: 1.2385 - val_accuracy: 0.5097
# Epoch 4/50
# 180/180 [==============================] - 72s 399ms/step - loss: 1.1917 - accuracy: 0.5159 - val_loss: 1.4687 - val_accuracy: 0.4249
# Epoch 5/50
# 180/180 [==============================] - 72s 398ms/step - loss: 1.0682 - accuracy: 0.5755 - val_loss: 0.9629 - val_accuracy: 0.6106
# Epoch 6/50
# 180/180 [==============================] - 73s 402ms/step - loss: 0.9792 - accuracy: 0.6094 - val_loss: 0.9720 - val_accuracy: 0.6113
# Epoch 7/50
# 180/180 [==============================] - 72s 401ms/step - loss: 0.8952 - accuracy: 0.6522 - val_loss: 1.0047 - val_accuracy: 0.5981
# Epoch 8/50
# 180/180 [==============================] - 73s 405ms/step - loss: 0.8671 - accuracy: 0.6601 - val_loss: 0.8683 - val_accuracy: 0.6558
# Epoch 9/50
# 180/180 [==============================] - 74s 409ms/step - loss: 0.8105 - accuracy: 0.6904 - val_loss: 0.8020 - val_accuracy: 0.6850
# Epoch 10/50
# 180/180 [==============================] - 73s 405ms/step - loss: 0.7593 - accuracy: 0.7120 - val_loss: 0.8030 - val_accuracy: 0.6898
# Epoch 11/50
# 180/180 [==============================] - 73s 404ms/step - loss: 0.7285 - accuracy: 0.7220 - val_loss: 0.7795 - val_accuracy: 0.6989
# Epoch 12/50
# 180/180 [==============================] - 74s 413ms/step - loss: 0.7031 - accuracy: 0.7334 - val_loss: 0.6848 - val_accuracy: 0.7476
# Epoch 13/50
# 180/180 [==============================] - 73s 405ms/step - loss: 0.6795 - accuracy: 0.7474 - val_loss: 0.7247 - val_accuracy: 0.7344
# Epoch 14/50
# 180/180 [==============================] - 73s 405ms/step - loss: 0.6581 - accuracy: 0.7526 - val_loss: 0.7290 - val_accuracy: 0.7218
# Epoch 15/50
# 180/180 [==============================] - 75s 414ms/step - loss: 0.6182 - accuracy: 0.7687 - val_loss: 0.6259 - val_accuracy: 0.7740
# Epoch 16/50
# 180/180 [==============================] - 73s 404ms/step - loss: 0.6043 - accuracy: 0.7717 - val_loss: 0.7332 - val_accuracy: 0.7149
# Epoch 17/50
# 180/180 [==============================] - 74s 412ms/step - loss: 0.5930 - accuracy: 0.7760 - val_loss: 0.6001 - val_accuracy: 0.7650
# Epoch 18/50
# 180/180 [==============================] - 74s 410ms/step - loss: 0.5803 - accuracy: 0.7817 - val_loss: 0.6207 - val_accuracy: 0.7531
# Epoch 19/50
# 180/180 [==============================] - 74s 412ms/step - loss: 0.5480 - accuracy: 0.7936 - val_loss: 0.5722 - val_accuracy: 0.7858
# Epoch 20/50
# 180/180 [==============================] - 74s 413ms/step - loss: 0.5398 - accuracy: 0.7950 - val_loss: 0.5839 - val_accuracy: 0.7761
# Epoch 21/50
# 180/180 [==============================] - 74s 411ms/step - loss: 0.5331 - accuracy: 0.8026 - val_loss: 0.6102 - val_accuracy: 0.7698
# Epoch 22/50
# 180/180 [==============================] - 73s 406ms/step - loss: 0.5266 - accuracy: 0.8043 - val_loss: 0.6556 - val_accuracy: 0.7580
# Epoch 23/50
# 180/180 [==============================] - 72s 402ms/step - loss: 0.5059 - accuracy: 0.8108 - val_loss: 0.6153 - val_accuracy: 0.7865
# Epoch 24/50
# 180/180 [==============================] - 73s 403ms/step - loss: 0.4957 - accuracy: 0.8145 - val_loss: 0.5455 - val_accuracy: 0.7969
# Epoch 25/50
# 180/180 [==============================] - 73s 403ms/step - loss: 0.4869 - accuracy: 0.8159 - val_loss: 0.6401 - val_accuracy: 0.7684
# Epoch 26/50
# 180/180 [==============================] - 75s 414ms/step - loss: 0.4782 - accuracy: 0.8212 - val_loss: 0.7185 - val_accuracy: 0.7434
# Epoch 27/50
# 180/180 [==============================] - 75s 416ms/step - loss: 0.4822 - accuracy: 0.8193 - val_loss: 0.5744 - val_accuracy: 0.7782
# Epoch 28/50
# 180/180 [==============================] - 74s 409ms/step - loss: 0.4675 - accuracy: 0.8267 - val_loss: 0.5413 - val_accuracy: 0.7962
# Epoch 29/50
# 180/180 [==============================] - 74s 410ms/step - loss: 0.4529 - accuracy: 0.8321 - val_loss: 0.4795 - val_accuracy: 0.8206
# Epoch 30/50
# 180/180 [==============================] - 74s 413ms/step - loss: 0.4388 - accuracy: 0.8359 - val_loss: 0.6264 - val_accuracy: 0.7733
# Epoch 31/50
# 180/180 [==============================] - 72s 401ms/step - loss: 0.4392 - accuracy: 0.8349 - val_loss: 0.5501 - val_accuracy: 0.7962
# Epoch 32/50
# 180/180 [==============================] - 72s 400ms/step - loss: 0.4259 - accuracy: 0.8342 - val_loss: 0.7567 - val_accuracy: 0.7357
# Epoch 33/50
# 180/180 [==============================] - 73s 405ms/step - loss: 0.4304 - accuracy: 0.8423 - val_loss: 0.6729 - val_accuracy: 0.7670
# Epoch 34/50
# 180/180 [==============================] - 72s 402ms/step - loss: 0.4104 - accuracy: 0.8475 - val_loss: 0.5840 - val_accuracy: 0.7830
# Epoch 35/50
# 180/180 [==============================] - 72s 399ms/step - loss: 0.4246 - accuracy: 0.8418 - val_loss: 0.5808 - val_accuracy: 0.7969
# Epoch 36/50
# 180/180 [==============================] - 73s 403ms/step - loss: 0.4037 - accuracy: 0.8545 - val_loss: 0.7335 - val_accuracy: 0.7490
# Epoch 37/50
# 180/180 [==============================] - 72s 399ms/step - loss: 0.4049 - accuracy: 0.8525 - val_loss: 0.6552 - val_accuracy: 0.7615
# Epoch 38/50
# 180/180 [==============================] - 71s 392ms/step - loss: 0.3872 - accuracy: 0.8542 - val_loss: 0.5137 - val_accuracy: 0.8164
# Epoch 39/50
# 180/180 [==============================] - 71s 392ms/step - loss: 0.3809 - accuracy: 0.8567 - val_loss: 0.5406 - val_accuracy: 0.8143
# Epoch 40/50
# 180/180 [==============================] - 71s 394ms/step - loss: 0.3726 - accuracy: 0.8609 - val_loss: 0.4903 - val_accuracy: 0.8150
# Epoch 41/50
# 180/180 [==============================] - 71s 393ms/step - loss: 0.3665 - accuracy: 0.8609 - val_loss: 0.6511 - val_accuracy: 0.7789
# Epoch 42/50
# 180/180 [==============================] - 71s 394ms/step - loss: 0.3646 - accuracy: 0.8636 - val_loss: 0.4777 - val_accuracy: 0.8359
# Epoch 43/50
# 180/180 [==============================] - 71s 392ms/step - loss: 0.3605 - accuracy: 0.8659 - val_loss: 0.5598 - val_accuracy: 0.8046
# Epoch 44/50
# 180/180 [==============================] - 70s 391ms/step - loss: 0.3592 - accuracy: 0.8664 - val_loss: 0.4730 - val_accuracy: 0.8296
# Epoch 45/50
# 180/180 [==============================] - 71s 392ms/step - loss: 0.3578 - accuracy: 0.8654 - val_loss: 0.5111 - val_accuracy: 0.8171
# Epoch 46/50
# 180/180 [==============================] - 71s 394ms/step - loss: 0.3612 - accuracy: 0.8665 - val_loss: 0.6340 - val_accuracy: 0.7803
# Epoch 47/50
# 180/180 [==============================] - 70s 390ms/step - loss: 0.3516 - accuracy: 0.8699 - val_loss: 0.5174 - val_accuracy: 0.8234
# Epoch 48/50
# 180/180 [==============================] - 70s 391ms/step - loss: 0.3387 - accuracy: 0.8761 - val_loss: 0.4747 - val_accuracy: 0.8303
# Epoch 49/50
# 180/180 [==============================] - 70s 391ms/step - loss: 0.3320 - accuracy: 0.8774 - val_loss: 0.5384 - val_accuracy: 0.8150
# Epoch 50/50
# 180/180 [==============================] - 70s 390ms/step - loss: 0.3375 - accuracy: 0.8765 - val_loss: 0.5142 - val_accuracy: 0.8053

# %%
classifier.evaluate(test_set)
# Out:
# 23/23 [==============================] - 3s 144ms/step - loss: 0.5142 - accuracy: 0.8053
# [0.5141944885253906, 0.8052850961685181]

# %%
pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')

# %%
training_set.class_indices
# Out:
# {'Anger': 0,
#  'Disgust': 1,
#  'Fear': 2,
#  'Happiness': 3,
#  'Sadness': 4,
#  'Surprise': 5}
